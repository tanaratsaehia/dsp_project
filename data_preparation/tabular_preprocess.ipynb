# %%
import pandas as pd
from preprocess_tabular import PreprocessAccel

pre_acc = PreprocessAccel(sampling_rate=50)

# %%
file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\hand\walking.csv"
data = pd.read_csv(file_path)
walking = pre_acc.segment_and_flatten_magnitude(label='walking', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\hand\sitting_standing_transition.csv"
data = pd.read_csv(file_path)
sitting_standing = pre_acc.segment_and_flatten_magnitude(label='sitting_standing', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\hand\running.csv"
data = pd.read_csv(file_path)
running = pre_acc.segment_and_flatten_magnitude(label='running', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\hand\descending_stairs.csv"
data = pd.read_csv(file_path)
desen_stairs = pre_acc.segment_and_flatten_magnitude(label='descending_stairs', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\hand\climbing_stairs.csv"
data = pd.read_csv(file_path)
climb_stairs = pre_acc.segment_and_flatten_magnitude(label='climbing_stairs', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

# %%
merge_df = pd.concat([walking, sitting_standing, running, desen_stairs, climb_stairs])
merge_df['label'].value_counts()
# Out:
# label
# walking              131
# running               86
# sitting_standing      80
# climbing_stairs       72
# descending_stairs     68
# Name: count, dtype: int64

# %%
file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\pocket\walking.csv"
data = pd.read_csv(file_path)
walking = pre_acc.segment_and_flatten_magnitude(label='walking', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\pocket\sitting_standing_transition.csv"
data = pd.read_csv(file_path)
sitting_standing = pre_acc.segment_and_flatten_magnitude(label='sitting_standing', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\pocket\running.csv"
data = pd.read_csv(file_path)
running = pre_acc.segment_and_flatten_magnitude(label='running', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\pocket\descending_stairs.csv"
data = pd.read_csv(file_path)
desen_stairs = pre_acc.segment_and_flatten_magnitude(label='descending_stairs', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

file_path = r"D:\git_repository\dsp_project\ignore_dir\datasets\clean_datasets\pocket\climbing_stairs.csv"
data = pd.read_csv(file_path)
climb_stairs = pre_acc.segment_and_flatten_magnitude(label='climbing_stairs', magnitude_column_name='magnitude', df=data, window_size_sec=5, overlap=0.5)

# %%
merge_df = pd.concat([merge_df, walking, sitting_standing, running, desen_stairs, climb_stairs])
merge_df['label'].value_counts()
# Out:
# label
# walking              270
# running              176
# sitting_standing     157
# climbing_stairs      139
# descending_stairs    133
# Name: count, dtype: int64

# %%
merge_df.shape
# Out:
# (875, 252)

# %%
merge_df.sample(10)
# Out:
#      start_time              label         x1         x2         x3  \
# 69       201264            running  20.518377  10.138190   6.462863
# 11        39204  descending_stairs  11.040679  11.523706  11.796444
# 89       254794            running   4.899041   2.734026   1.433213
# 98       265101            walking   6.185216   5.919029   6.325385
# 37       115695            running  10.856915  27.907089  49.471379
# 129      370257            walking  10.098158   9.586704   9.220705
# 3         22063    climbing_stairs  12.978837  13.783225  11.245999
# 55       161610            walking  12.466579  14.161518  16.542723
# 7         31187  descending_stairs   6.047189   7.619245   7.619245
# 10        35213   sitting_standing   6.206005   6.165363   6.200823
#
#             x4         x5         x6         x7         x8  ...       x241  \
# 69    4.100012   2.891954   2.146392   1.871497   2.756701  ...  10.608775
# ...

# %%
merge_df.to_csv('cleaned_combine_all_class_with_label_no_fft.csv', index=False)

# %%
merge_df.head()
# Out:
#    start_time    label        x1         x2         x3         x4         x5  \
# 0          29  walking  9.391768   9.095416   9.116803   9.038429   8.920207
# 1        2791  walking  9.339839   9.334993   9.274880   9.153142   9.202418
# 2        5603  walking  9.394136   9.231343   9.252686   9.257068   9.281385
# 3        8420  walking  7.183794   7.151433   6.730669   6.369309   7.059695
# 4       11241  walking  9.832197  10.361916  10.715456  10.929579  11.233561
#
#           x6         x7         x8  ...       x241       x242      x243  \
# 0   9.119304   9.344565   9.368447  ...   9.120713   9.209533  9.354902
# 1   9.314295   9.340177   9.350540  ...  10.843081   9.170971  7.791438
# 2   9.294100   9.152972   9.336755  ...  10.808816  10.393205  9.804173
# 3   7.495365   8.232169   8.581987  ...   6.619653   7.446160  7.250531
# 4  11.865534  13.391049  14.774566  ...   8.623207   7.681159  7.276771
#
# ...

# %%
fft_df = pre_acc.compute_fft_on_flattened_data(merge_df)
fft_df.sample(10)
# Out:
#      start_time              label         x1         x2         x3  \
# 206      209077   sitting_standing  29.356931  35.334344  86.096848
# 296      254059            running   6.125446   9.326554  10.758832
# 391       81330    climbing_stairs   3.485472   3.161119   8.494474
# 588       43425   sitting_standing   3.883213   4.126115   7.313832
# 554      314919            walking  17.761416  18.532893  31.365311
# 505      186511            walking  19.640186  20.118365  24.797851
# 806      189659  descending_stairs  22.330901  22.877394  26.761271
# 740      249429            running  33.602443  34.938743  55.616149
# 135       19140   sitting_standing  10.604737   8.508215  48.797150
# 376       41490    climbing_stairs  17.220266  17.962130  25.006376
#
#             x4          x5          x6         x7          x8  ...      x117  \
# 206  54.551607  158.706165  203.578273  12.763688  207.061138  ...  0.485088
# ...

# %%
fft_df.to_csv('cleaned_combine_all_class_with_label_applied_fft.csv', index=False)
